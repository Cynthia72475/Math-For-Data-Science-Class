# %%
# ================================================================
# Title: Assignment 5.2 - Riemann Sum Function
# Author: zhuowei(GitHub username)
# Date: 1/25/2025
# Modified By: Cyndie Cramer
# Description: Right Riemann Sum Calculator
# =================================================================

import math  # Allows use of math functions if needed (like sin, cos, etc.)

def right_riemann_sum(f, a, b, n):
    """
    Calculates the right Riemann sum R_n for a function f on the interval [a, b].

    f : the function we are finding the area under
    a : the left endpoint of the interval
    b : the right endpoint of the interval
    n : the number of rectangles
    """

    # Step 1: Find the width of each rectangle (Δx)
    # This is the total interval length divided by the number of rectangles
    delta_x = (b - a) / n

    # Step 2: Start with a total area of 0
    total_area = 0

    # Step 3: Loop through each rectangle using RIGHT endpoints
    # We start at k = 1 and go to n because right Riemann sums
    # use the right side of each rectangle
    for k in range(1, n + 1):

        # Step 4: Find the x-value of the right endpoint
        x = a + k * delta_x

        # Step 5: Evaluate the function at this x-value
        height = f(x)

        # Step 6: Multiply height by width to get rectangle area
        rectangle_area = height * delta_x

        # Step 7: Add the rectangle area to the total
        total_area += rectangle_area

    # Step 8: Return the final estimated area
    return total_area


# Step 9: Define the function f(x)
# This example uses f(x) = x^2
def f(x):
    return x**2

# Step 10: Set the interval [a, b]
a = 0
b = 2

# Step 11: Choose how many rectangles to use
n = 10

# Step 12: Call the function and store the result
result = right_riemann_sum(f, a, b, n)

# Step 13: Print the result to the screen
print("Right Riemann Sum:", result)
# Out:
# Right Riemann Sum: 3.080000000000001

# %%
# ================================================================
# Title: Assignment 5.2 - Riemann Sum Function
# Author: zhuowei(GitHub username)
# Date: 1/25/2025
# Modified By: Cyndie Cramer
# Description: Right Riemann Sum Calculator
# =================================================================

import math  # Allows use of math functions if needed (like sin, cos, etc.)

def right_riemann_sum(f, a, b, n):
    """
    Calculates the right Riemann sum R_n for a function f on the interval [a, b].

    f : the function we are finding the area under
    a : the left endpoint of the interval
    b : the right endpoint of the interval
    n : the number of rectangles
    """

    # Step 1: Find the width of each rectangle (Δx)
    # This is the total interval length divided by the number of rectangles
    delta_x = (b - a) / n

    # Step 2: Start with a total area of 0
    total_area = 0

    # Step 3: Loop through each rectangle using RIGHT endpoints
    # We start at k = 1 and go to n because right Riemann sums
    # use the right side of each rectangle
    for k in range(1, n + 1):

        # Step 4: Find the x-value of the right endpoint
        x = a + k * delta_x

        # Step 5: Evaluate the function at this x-value
        height = f(x)

        # Step 6: Multiply height by width to get rectangle area
        rectangle_area = height * delta_x

        # Step 7: Add the rectangle area to the total
        total_area += rectangle_area

    # Step 8: Return the final estimated area
    return total_area


# Step 9: Define the function f(x)
# This example uses f(x) = x^2
def f(x):
    return x**2

# Step 10: Set the interval [a, b]
a = 0
b = 2

# Step 11: Choose how many rectangles to use
n = 10

# Step 12: Call the function and store the result
result = right_riemann_sum(f, a, b, n)

# Step 13: Print the result to the screen
print("Right Riemann Sum:", result)
# Out:
# Right Riemann Sum: 3.080000000000001
